# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Case 1

age_x=[25,26,27,29,33,32,35,28,35,39]
devop=[3525,3326,3627,3129,3633,3032,3115,3628,3435,3009]
javadop=[4525,5326,5627,5129,5633,5032,6115,6628,6435,6009]
age_x.sort()
devop.sort()
javadop.sort()

# %%
plt.plot(age_x,devop,label="All devep")
plt.plot(age_x,javadop,label="All Java ")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.legend()

# %%
# Case 2

age_x=np.random.normal(35,5,10)
devop=np.random.normal(35000,10000,10)
javadop=np.random.normal(50000,5000,10)
age_x.sort()
devop.sort()
javadop.sort()

plt.plot(age_x,devop,label="All devep")
plt.plot(age_x,javadop,label="All Java ")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.legend()

# %%
plt.scatter(age_x,devop)

# %%
plt.bar(age_x,devop)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.plot(age_x,linestyle="dotted")

# %%
plt.hist(age_x)
# Out:
# (array([1., 0., 0., 0., 0., 1., 2., 3., 2., 1.]),
#  array([19.58519608, 21.81908683, 24.05297757, 26.28686832, 28.52075906,
#         30.75464981, 32.98854056, 35.2224313 , 37.45632205, 39.6902128 ,
#         41.92410354]),
#  <BarContainer object of 10 artists>)
